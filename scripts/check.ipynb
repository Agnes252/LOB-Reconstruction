# %%
import pandas as pd
import numpy as np
import os
import tempfile
import sys

result_path = 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmpkuydd3d9.parquet'

# %%
result = pd.read_parquet(result_path, engine='pyarrow')
print(result)
# Out:
#        security_id  timestamp_ms  phase  mid_price  spread  sheet_diff   open  \
# 0           000400      32400000      1        NaN     NaN         NaN    NaN
# 1           000400      32400050      1        NaN     NaN         NaN    NaN
# 2           000400      32400100      1        NaN     NaN         NaN    NaN
# 3           000400      32400150      1        NaN     NaN         NaN    NaN
# 4           000400      32400200      1        NaN     NaN         NaN    NaN
# ...            ...           ...    ...        ...     ...         ...    ...
# 431996      000400      53999800      6     17.440    0.00    0.000000    NaN
# 431997      000400      53999850      6     17.440    0.00    0.000000    NaN
# 431998      000400      53999900      8     56.405  -96.67   -0.428571  20.63
# 431999      000400      53999950      8     56.405  -96.67   -0.428571    NaN
# 432000      000400      54000000      8     47.510  -78.60    0.175758  20.63
#
# ...

# %%
result.columns.tolist()
# Out:
# ['security_id',
#  'timestamp_ms',
#  'phase',
#  'mid_price',
#  'spread',
#  'sheet_diff',
#  'open',
#  'high',
#  'low',
#  'close',
#  'volume',
#  'turnover',
#  'num_trades',
#  'buy_volume',
#  'sell_volume',
#  'match_diff',
#  'order_diff',
#  'cancel_diff',
#  'ofi',
#  'ofi_norm',
#  'last_price',
#  'cum_volume',
#  'cum_turnover',
#  'is_anomaly',
#  'anomaly_count',
#  'ask_px_1',
#  'ask_vol_1',
#  'ask_cnt_1',
#  'bid_px_1',
#  'bid_vol_1',
#  'bid_cnt_1',
#  'ask_px_2',
#  'ask_vol_2',
#  'ask_cnt_2',
#  'bid_px_2',
#  'bid_vol_2',
#  'bid_cnt_2',
#  'ask_px_3',
#  'ask_vol_3',
#  'ask_cnt_3',
#  'bid_px_3',
#  'bid_vol_3',
#  'bid_cnt_3',
#  'ask_px_4',
#  'ask_vol_4',
#  'ask_cnt_4',
#  'bid_px_4',
#  'bid_vol_4',
#  'bid_cnt_4',
#  'ask_px_5',
#  'ask_vol_5',
#  'ask_cnt_5',
#  'bid_px_5',
#  'bid_vol_5',
#  'bid_cnt_5',
#  'ask_px_6',
#  'ask_vol_6',
#  'ask_cnt_6',
#  'bid_px_6',
#  'bid_vol_6',
#  'bid_cnt_6',
#  'ask_px_7',
#  'ask_vol_7',
#  'ask_cnt_7',
# ...

# %%
result['security_id'].value_counts()
# Out:
# security_id
# 000400    432001
# Name: count, dtype: int64
